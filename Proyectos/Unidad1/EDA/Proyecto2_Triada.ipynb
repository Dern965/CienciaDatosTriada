# %% [markdown]
# # Proyecto 2: EDA

# %% [markdown]
# ## Integrantes
# * García Saavedra Armando
# * Orozco Guillen Jorge David
# * Rodriguez Nuñez Diego Eduardo

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Enfoque no gráfico

# %% [markdown]
# ### Impotación de datos

# %%
sp = pd.read_csv('./data/StudentsPerformance.csv')
sp
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %% [markdown]
# Obtenemos la forma del dataset, en este caso tiene 1000 registros con 8 atributos

# %%
sp.shape
# Out:
# (1000, 8)

# %% [markdown]
# Obtenemos la info del dataset, para saber si hay valores nulos, el tipo y nombre de las columnas

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race_ethnicity               1000 non-null   object
#  2   parental_level_of_education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test_preparation_course      1000 non-null   object
#  5   math_score                   1000 non-null   int64
#  6   reading_score                1000 non-null   int64
#  7   writing_score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# Obtenemos los datos estádisticos del dataset

# %%
sp.describe()
# Out:
#        math_score  reading_score  writing_score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Revisamos los primeros 10 registros

# %%
sp.head(10)
# Out:
#    gender race_ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %% [markdown]
# Y los ultimos 10 registros

# %%
sp.tail(10)
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# 990               completed          86             81             75
# ...

# %% [markdown]
# Contamos cuantas personas hay por genero

# %%
sp.value_counts('gender').reset_index(name='Cantidad')
# Out:
#    gender  Cantidad
# 0  female       518
# 1    male       482

# %% [markdown]
# Contamos cuantas personas hay por raza étnica

# %%
sp.value_counts('race_ethnicity').reset_index(name='Cantidad')
# Out:
#   race_ethnicity  Cantidad
# 0        group C       319
# 1        group D       262
# 2        group B       190
# 3        group E       140
# 4        group A        89

# %% [markdown]
# # Limpieza de datos

# %% [markdown]
# Eliminamos datos duplicados

# %%
sp_dnt = sp.drop_duplicates()
sp_dnt
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %% [markdown]
# En este caso no hubo elementos repetidos, procedemos a encontrar valores nulos

# %%
sp.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %% [markdown]
# Como no hubo elementos repetidos ni nulos procedemos al análisis gráfico

# %% [markdown]
# Pero antes cambiamos el nombre de las columnas para una mayor comodidad al manejar los datos

# %%
sp = sp.rename(columns={
    'race_ethnicity': 'ethnicity',
    'parental_level_of_education' : 'parental_education',
    'test_preparation_course': 'course'
})

# %% [markdown]
# # Análisis Univariado

# %%
sp.head()
# Out:
#    gender ethnicity  parental_education         lunch     course  math_score  \
# 0  female   group B   bachelor's degree      standard       none          72
# 1  female   group C        some college      standard  completed          69
# 2  female   group B     master's degree      standard       none          90
# 3    male   group A  associate's degree  free/reduced       none          47
# 4    male   group C        some college      standard       none          76
#
#    reading_score  writing_score
# 0             72             74
# 1             90             88
# 2             95             93
# 3             57             44
# 4             78             75

# %%
plt.title("Distribución por género")
sns.countplot(data=sp,x='gender')
plt.show()

# %%
plt.title("Distribución por etnias")
sns.countplot(data=sp,x='ethnicity')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title("Distribución por educación de los padres")
sns.countplot(data=sp,x='parental_education')
plt.show()

# %%
plt.title("Distribución por lunch")
sns.countplot(data=sp,x='lunch')
plt.show()

# %%
plt.title("Distribución por curso")
sns.countplot(data=sp,x='course')
plt.show()

# %% [markdown]
# Como se puede observar la mayoria de estudiantes ***No*** recibieron algun curso de preparación

# %%
plt.title("Distribución por puntaje de matemáticas")
sns.histplot(data=sp, x='math_score',color="red",kde=True)
plt.show()

# %%
plt.title("Distribución por puntaje de lectura")
sns.histplot(data=sp, x='reading_score',color="skyblue",kde=True)
plt.show()

# %%
plt.title("Distribución por puntaje de escritura")
sns.histplot(data=sp, x='writing_score',color="skyblue",kde=True)
plt.show()

# %% [markdown]
# De estos histogramas podemos concluir que la mayoria de estudiante obtuvieron un puntaje entre 60 a 80 en los 3 exámenes

# %% [markdown]
# ## Gráficamos las tendencias de los puntajes

# %%
plt.title("Calificaciones de las materias")
sp[['math_score','reading_score','writing_score']].boxplot()
plt.show()

# %% [markdown]
# # Análisis Multivariable

# %% [markdown]
# ***
# ## Calificaciones por genero

# %%
sns.pairplot(sp,hue='gender')

# %%
df_grupo = sp.groupby('gender').mean()
plt.figure(figsize=(6,6))
plt.pie(df_grupo['math_score'],labels=df_grupo.index, autopct='%1.1f%%')
plt.title("Distribución del puntaje de matemáticas por género")
plt.legend()
plt.show()
# Out:
# C:\Users\dern9\AppData\Local\Temp\ipykernel_14288\3380748291.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grupo = sp.groupby('gender').mean()

# %%
plt.figure(figsize=(6,6))
plt.pie(df_grupo['reading_score'],labels=df_grupo.index, autopct='%1.1f%%')
plt.title("Distribución del puntaje de lectura de lectura por género")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(df_grupo['writing_score'],labels=df_grupo.index, autopct='%1.1f%%')
plt.title("Distribución del puntaje de escritura por género")
plt.legend()
plt.show()

# %% [markdown]
# ***
# ## Calificaciones por etnia

# %%
sns.pairplot(sp,hue='ethnicity')

# %%
df_etnia = sp.groupby('ethnicity').mean()
plt.figure(figsize=(6,6))
plt.pie(df_etnia['math_score'],labels=df_etnia.index, autopct='%1.1f%%')
plt.title("Distribución del puntaje de matemáticas por etnia")
plt.legend()
plt.show()
# Out:
# C:\Users\dern9\AppData\Local\Temp\ipykernel_14288\2083202051.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_etnia = sp.groupby('ethnicity').mean()

# %%
plt.figure(figsize=(6,6))
plt.pie(df_etnia['reading_score'],labels=df_etnia.index, autopct='%1.1f%%')
plt.title("Distribución del puntaje de lectura por etnia")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.pie(df_etnia['writing_score'],labels=df_etnia.index, autopct='%1.1f%%')
plt.title("Distribución del puntaje de escritura por etnia")
plt.legend()
plt.show()

# %% [markdown]
# ***
# ## Calificaciones por curso de preparación

# %%
sns.pairplot(sp,hue='course')

# %%
df_curso = sp.groupby('course').mean()
plt.figure(figsize=(6,6))
plt.title("Distribución del puntaje de matemáticas por curso")
plt.pie(df_curso['math_score'],labels=df_curso.index,autopct='%1.1f%%')
plt.legend()
plt.show()
# Out:
# C:\Users\dern9\AppData\Local\Temp\ipykernel_14288\3173402025.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_curso = sp.groupby('course').mean()

# %%
plt.figure(figsize=(6,6))
plt.title("Distribución del puntaje de lectura por curso")
plt.pie(df_curso['reading_score'],labels=df_curso.index,autopct='%1.1f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.title("Distribución del puntaje de escritura por curso")
plt.pie(df_curso['writing_score'],labels=df_curso.index,autopct='%1.1f%%')
plt.legend()
plt.show()

# %% [markdown]
# ***
# ## Calificaciones por lunch

# %%
sns.pairplot(sp,hue='lunch')

# %%
df_lunch = sp.groupby('lunch').mean()
plt.figure(figsize=(6,6))
plt.title("Distribución del puntaje de matemáticas por lunch")
plt.pie(df_lunch['math_score'],labels=df_lunch.index,autopct='%1.1f%%')
plt.legend()
plt.show()
# Out:
# C:\Users\dern9\AppData\Local\Temp\ipykernel_14288\2086023372.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_lunch = sp.groupby('lunch').mean()

# %%
plt.figure(figsize=(6,6))
plt.title("Distribución del puntaje de lectura por lunch")
plt.pie(df_lunch['reading_score'],labels=df_lunch.index,autopct='%1.1f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.title("Distribución del puntaje de escritura por lunch")
plt.pie(df_lunch['writing_score'],labels=df_lunch.index,autopct='%1.1f%%')
plt.legend()
plt.show()

# %% [markdown]
# ***
# ## Calificaciones por educación parental

# %%
sns.pairplot(sp,hue='parental_education')

# %%
df_pared = sp.groupby('parental_education').mean()
plt.figure(figsize=(6,6))
plt.title("Distribución del puntaje de matemáticas por educacion parental")
plt.pie(df_pared['math_score'],labels=df_pared.index,autopct='%1.1f%%')
plt.legend()
plt.show()
# Out:
# C:\Users\dern9\AppData\Local\Temp\ipykernel_14288\3326708096.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_pared = sp.groupby('parental_education').mean()

# %%
plt.figure(figsize=(6,6))
plt.title("Distribución del puntaje de lectura por educacion parental")
plt.pie(df_pared['reading_score'],labels=df_pared.index,autopct='%1.1f%%')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.title("Distribución del puntaje de escritura por educacion parental")
plt.pie(df_pared['writing_score'],labels=df_pared.index,autopct='%1.1f%%')
plt.legend()
plt.show()

# %% [markdown]
# ***
# ## Correlación

# %%
sp.corr()
# Out:
# C:\Users\dern9\AppData\Local\Temp\ipykernel_14288\1788210350.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sp.corr()
#                math_score  reading_score  writing_score
# math_score       1.000000       0.817580       0.802642
# reading_score    0.817580       1.000000       0.954598
# writing_score    0.802642       0.954598       1.000000

# %%
sns.heatmap(sp.corr(),vmin=-1,vmax=1, cmap= 'magma',annot=True)
# Out:
# C:\Users\dern9\AppData\Local\Temp\ipykernel_14288\1161250209.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sp.corr(),vmin=-1,vmax=1, cmap= 'magma',annot=True)
# <Axes: >

# %% [markdown]
# ***
# # Hipótesis

# %% [markdown]
# Podriamos obtener el promedio de los estudiantes

# %%
df_prom = (
    sp.assign(
    mean = (sp.math_score + sp.reading_score + sp.writing_score)/3
    )
)

df_prom
# Out:
#      gender ethnicity  parental_education         lunch     course  \
# 0    female   group B   bachelor's degree      standard       none
# 1    female   group C        some college      standard  completed
# 2    female   group B     master's degree      standard       none
# 3      male   group A  associate's degree  free/reduced       none
# 4      male   group C        some college      standard       none
# ..      ...       ...                 ...           ...        ...
# 995  female   group E     master's degree      standard  completed
# 996    male   group C         high school  free/reduced       none
# 997  female   group C         high school  free/reduced  completed
# 998  female   group D        some college      standard  completed
# 999  female   group D        some college  free/reduced       none
#
#      math_score  reading_score  writing_score       mean
# 0            72             72             74  72.666667
# ...

# %% [markdown]
# Discriminamos a los alumnos con promedio superior a 8.5

# %%
df_desal = df_prom.loc[df_prom['mean']>85]
df_desal
# Out:
#      gender ethnicity  parental_education     lunch     course  math_score  \
# 2    female   group B     master's degree  standard       none          90
# 6    female   group B        some college  standard  completed          88
# 16     male   group C         high school  standard       none          88
# 34     male   group E        some college  standard       none          97
# 94   female   group B        some college  standard       none          79
# ..      ...       ...                 ...       ...        ...         ...
# 962  female   group E  associate's degree  standard       none         100
# 970  female   group D   bachelor's degree  standard       none          89
# 979  female   group C  associate's degree  standard       none          91
# 983  female   group A        some college  standard  completed          78
# 995  female   group E     master's degree  standard  completed          88
#
#      reading_score  writing_score        mean
# ...

# %% [markdown]
# Procedemos a graficar la misma info pero con los datos de alumnos de desempeño alto

# %% [markdown]
# ***
# ### Dado su género

# %%
sns.pairplot(df_desal,hue='gender')
